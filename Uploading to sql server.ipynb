# %%
import psycopg2 as pg2 
import pandas as pd

# %%
data = pd.read_html('https://en.wikipedia.org/wiki/Programming_languages_used_in_most_popular_websites')

# %%
df = data[0]

# %%
df
# Out:
#          Websites Popularity (unique visitors per month)[1]  \
# 0       Google[2]                                2800000000
# 1        Facebook                                1120000000
# 2         YouTube                                1100000000
# 3           Yahoo                                 750000000
# 4            Etsy       516,000,000 (Total, not unique)[14]
# 5          Amazon                         2,400,000,000[18]
# 6       Wikipedia                                 475000000
# 7          Fandom                           315,000,000[22]
# 8         Twitter                                 290000000
# 9            Bing                                 285000000
# 10           eBay                                 285000000
# 11            MSN                                 280000000
# 12       LinkedIn                                 260000000
# 13      Pinterest                                 250000000
# 14  WordPress.com                          240,000,000 [35]
# ...

# %%
df = df.drop([15,14,7,4])

# %%
df
# Out:
#      Websites Popularity (unique visitors per month)[1]  \
# 0   Google[2]                                2800000000
# 1    Facebook                                1120000000
# 2     YouTube                                1100000000
# 3       Yahoo                                 750000000
# 5      Amazon                         2,400,000,000[18]
# 6   Wikipedia                                 475000000
# 8     Twitter                                 290000000
# 9        Bing                                 285000000
# 10       eBay                                 285000000
# 11        MSN                                 280000000
# 12   LinkedIn                                 260000000
# 13  Pinterest                                 250000000
#
#          Front-end (Client-side)  \
# 0         JavaScript, TypeScript
# 1   JavaScript, Typescript, Flow
# 2         JavaScript, TypeScript
# 3                     JavaScript
# 5                     JavaScript
# ...

# %%
df = df.drop(5)

# %%
df
# Out:
#      Websites Popularity (unique visitors per month)[1]  \
# 0   Google[2]                                2800000000
# 1    Facebook                                1120000000
# 2     YouTube                                1100000000
# 3       Yahoo                                 750000000
# 6   Wikipedia                                 475000000
# 8     Twitter                                 290000000
# 9        Bing                                 285000000
# 10       eBay                                 285000000
# 11        MSN                                 280000000
# 12   LinkedIn                                 260000000
# 13  Pinterest                                 250000000
#
#          Front-end (Client-side)  \
# 0         JavaScript, TypeScript
# 1   JavaScript, Typescript, Flow
# 2         JavaScript, TypeScript
# 3                     JavaScript
# 6                     JavaScript
# 8                     JavaScript
# 9                     JavaScript
# ...

# %%
df = df.rename(columns = {'Popularity (unique visitors per month)[1]':'Popularity'
                         ,'Front-end (Client-side)':'Front_end'
                         ,'Back-end(Server-side)':'back_end'})

# %%
conn = pg2.connect(host = "localhost",port = 5432 , dbname="Programming_language", user="postgres", password = "hamzaowais1")

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:hamzaowais1@localhost:5432/Programming_language')

# %%
df.to_sql('popular_languages',engine, if_exists='replace', index = False)
# Out:
# 11
